# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import json
import requests
url = "https://data.gov.il/api/3/action/datastore_search?resource_id=8a51c65b-f95a-4fb8-bd97-65f47109f41f&limit=990"
response = requests.get(url)
response_j = response.content
response_d = json.loads(response_j)
#print (type(response_d))
#response_d = ["iss_position"]

import urllib
#url = 'https://data.gov.il/api/3/action/datastore_search?resource_id=8a51c65b-f95a-4fb8-bd97-65f47109f41f&limit=5&q=title:jones'  
#fileobj = urllib.urlopen(url)
#print (fileobj.read())


#file = urllib.urlopen("https://data.gov.il/api/3/action/datastore_search?resource_id=8a51c65b-f95a-4fb8-bd97-65f47109f41f&limit=5&q=title:jones")
#s = file.read()
#f.close()

#I'm guessing this would output the html source code?
#print(s)



#import urllib.request

#with urllib.request.urlopen("https://data.gov.il/api/3/action/datastore_search?resource_id=8a51c65b-f95a-4fb8-bd97-65f47109f41f&limit=990&q=title:jones") as url:
   # s = url.read()
    # I'm guessing this would output the html source code ?
#response_d = json.loads(response_j)
#response_d



url = "https://he.wikipedia.org/wiki/%D7%AA%D7%91%D7%A0%D7%99%D7%AA:%D7%A8%D7%99%D7%9B%D7%95%D7%96_%D7%98%D7%91%D7%9C%D7%90%D7%95%D7%AA_%D7%9E%D7%92%D7%A4%D7%AA_%D7%94%D7%A7%D7%95%D7%A8%D7%95%D7%A0%D7%94"
r = requests.get(url)

soup = bs(r.content)
contents = soup.prettify()

info_box = soup.find(class_="wikitable")
print (info_box.prettify())
# Out:
# <table class="wikitable" style="float: right; clear: right; padding: 0; margin-right: 0.5em;">
#  <tbody>
#   <tr>
#    <td>
#     <div class="tabWrapper">
#      <ul>
#       <li>
#        <a href="#corona_World">
#         כל העולם
#        </a>
#       </li>
#       <li>
#        <a href="#corona_USA">
#         ארצות הברית
#        </a>
#       </li>
#       <li>
#        <a href="#corona_EA">
#         האיחוד האירופי
#        </a>
#       </li>
#       <li>
#        <a href="#corona_India">
#         הודו
#        </a>
#       </li>
#       <li>
#        <a href="#corona_Israel">
#         ישראל
#        </a>
#       </li>
#       <li>
#        <a href="#corona_PA">
#         רש"פ
#        </a>
#       </li>
#      </ul>
#      <div id="corona_World" style="padding: 0; margin: 0;">
#       <table class="wikitable" style="float: left; clear: left; padding: 0; margin-right: 0.5em;">
#        <tbody>
#         <tr>
#          <td>
# ...
